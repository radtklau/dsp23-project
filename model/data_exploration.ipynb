# %%
print("hello world")
import pandas as pd
# Out:
# hello world

# %%
path = '../data/train.csv'
dataset = pd.read_csv(path)

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
dataset.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
dataset.shape
# Out:
# (1460, 81)

# %%
# %config InteractiveShell.ast_node_interactivity = 'all'

# %%
dataset.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
missing_indices = dataset[dataset['MiscVal'].isna()].index
dataset['MiscVal'][missing_indices[0]:missing_indices[0]+15]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\49176\dsp23-project\model\data_exploration.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/49176/dsp23-project/model/data_exploration.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> missing_indices = dataset[dataset['MiscVal'].isna()].index
# ----> <a href='vscode-notebook-cell:/c%3A/Users/49176/dsp23-project/model/data_exploration.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> dataset['MiscVal'][missing_indices[0]:missing_indices[0]+15]
#
# File c:\Users\49176\miniconda3\envs\ml\lib\site-packages\pandas\core\indexes\base.py:5365, in Index.__getitem__(self, key)
#    5362 if is_integer(key) or is_float(key):
#    5363     # GH#44051 exclude bool, which would return a 2d ndarray
#    5364     key = com.cast_scalar_indexer(key)
# -> 5365     return getitem(key)
#    5367 if isinstance(key, slice):
# ...

# %%
dataset['MiscVal'].value_counts()
dataset['MiscVal'].unique()
# Out:
# MiscVal
# 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 600         4
# 2000        4
# 1200        2
# 480         2
# 15500       1
# 800         1
# 350         1
# 3500        1
# 1300        1
# 54          1
# 620         1
# 560         1
# 1400        1
# 8300        1
# 1150        1
# 2500        1
# Name: count, dtype: int64
# array([    0,   700,   350,   500,   400,   480,   450, 15500,  1200,
#          800,  2000,   600,  3500,  1300,    54,   620,   560,  1400,
#         8300,  1150,  2500], dtype=int64)

# %%
#TODO
#1. replace nan with 'NA' in categorical variables (if dtype == object)
#2. replace nan with 0 in numerical variables (if dtype == float64 or dtype == int64)
#3. except for 'GarageYrBlt', replace it with avg of this column

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
for column in dataset:
    if dataset[column].dtype == object: #categorical feature
        dataset[column] = dataset[column].fillna('NA')

# %%
values = [['NA', 'Po', 'Fa', 'TA', 'Gd']]
for column in dataset.columns:
    #print(dataset[column].dtype )
    if column == 'BsmtCond':
        encoder = OrdinalEncoder(categories=values)
        X_encoded = encoder.fit_transform(dataset[column].values.reshape(-1,1))
        break
    
print(X_encoded.shape)
# Out:
# (1460, 1)

# %%
del dataset["BsmtHalfBath"]
print(dataset.shape)
# Out:
# (1460, 78)

# %%
feat_ordinal_dict = {
    # Considers 'missing' as 'neutral'
    # Take the order is important as the ordinal encoders will label the categories in the order of the list.
    'BsmtCond': ['NA', 'Po', 'Fa', 'TA', 'Gd'],
    'BsmtExposure': ['NA', 'No', 'Mn', 'Av', 'Gd'],
    'BsmtFinType1': ['NA', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ'],
    'BsmtFinType2': ['NA', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ'],
    'BsmtQual': ['NA', 'Fa', 'TA', 'Gd', 'Ex'],
    'Electrical': ['NA', 'Mix', 'FuseP', 'FuseF', 'FuseA', 'SBrkr'],
    'ExterCond': ['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
    'ExterQual': ['NA', 'Fa', 'TA', 'Gd', 'Ex'],
    'FireplaceQu': ['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
    'Functional': ['NA', 'Sev', 'Maj2', 'Maj1', 'Mod', 'Min2', 'Min1', 'Typ'],
    'GarageCond': ['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
    'GarageFinish': ['NA', 'Unf', 'RFn', 'Fin'],
    'GarageQual': ['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
    'HeatingQC': ['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
    'KitchenQual': ['NA', 'Fa', 'TA', 'Gd', 'Ex'],
    'LandContour': ['NA', 'Low', 'Bnk', 'HLS', 'Lvl'],
    'LandSlope': ['NA', 'Sev', 'Mod', 'Gtl'],
    'LotShape': ['NA', 'IR3', 'IR2', 'IR1', 'Reg'],
    'PavedDrive': ['NA', 'N', 'P', 'Y'],
}
import numpy as np

# %%
count = 0
for column in dataset.columns:
    if dataset[column].dtype == object: #categorical feature
        dataset[column] = dataset[column].fillna('NA')
        
        if column in feat_ordinal_dict.keys(): #ordinal feature
            possible_values = feat_ordinal_dict[column].reshape(1,-1)
            encoder = OrdinalEncoder(categories=possible_values)
            encoded_column = encoder.fit_transform(dataset[column].values.reshape(-1,1)) #encodes as float64
            dataset[column] = encoded_column
        else: #nominal features 
            count += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\49176\dsp23-project\model\data_exploration.ipynb Cell 17 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/49176/dsp23-project/model/data_exploration.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> dataset[column] = dataset[column].fillna('NA')
#       <a href='vscode-notebook-cell:/c%3A/Users/49176/dsp23-project/model/data_exploration.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a> if column in feat_ordinal_dict.keys(): #ordinal feature
# ----> <a href='vscode-notebook-cell:/c%3A/Users/49176/dsp23-project/model/data_exploration.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a>     possible_values = feat_ordinal_dict[column].reshape(1,-1)
#       <a href='vscode-notebook-cell:/c%3A/Users/49176/dsp23-project/model/data_exploration.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a>     encoder = OrdinalEncoder(categories=possible_values)
# ...
